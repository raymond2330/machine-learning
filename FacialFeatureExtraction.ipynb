# %% [markdown]
# # Facial Emotion Feature Extraction
# ### Raymond Postrero
# ### CS41S2

# %%
# !pip install opencv-python 
# !pip install dlib
# !pip install pandas
# !pip install matplotlib
# Out:
# ...
#   Using cached dlib-19.24.6.tar.gz (3.4 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py clean for dlib
# Failed to build dlib
# ...
#   Running setup.py install for dlib: started
#   Running setup.py install for dlib: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [41 lines of output]
#       running bdist_wheel
#       running build
#       running build_ext
#
# ...
#
#                          CMake is not installed on your system!
#
#           Or it is possible some broken copy of cmake is installed on your system.
#           It is unfortunately very common for python package managers to include
#           broken copies of cmake.  So if the error above this refers to some file
#           path to a cmake file inside a python or anaconda or miniconda path then you
# ...

# %%
# !pip install dlib
# Out:
# ...
#   Using cached dlib-19.24.6.tar.gz (3.4 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py clean for dlib
# Failed to build dlib
# ...
#   Running setup.py install for dlib: started
#   Running setup.py install for dlib: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [41 lines of output]
#       running bdist_wheel
#       running build
#       running build_ext
#
# ...
#
#                          CMake is not installed on your system!
#
#           Or it is possible some broken copy of cmake is installed on your system.
#           It is unfortunately very common for python package managers to include
#           broken copies of cmake.  So if the error above this refers to some file
#           path to a cmake file inside a python or anaconda or miniconda path then you
# ...

# %%
import os 
import cv2 
import dlib 
import pandas as pd 
import matplotlib.pyplot as plt

# Path to the JAFFE dataset
dataset_path = 'jaffedbase'

# Load the images
images = []
image_filenames = []
for filenames in os.listdir(dataset_path):
    if filenames.endswith('.tiff'):
        image = cv2.imread(os.path.join(dataset_path, filenames))
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        images.append(image)
        image_filenames.append(filenames)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26568\3907108405.py in <module>
#       1 import os
#       2 import cv2
# ----> 3 import dlib
#       4 import pandas as pd
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'dlib'

# %%
# !pip install imutils
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25854 sha256=63abb5985919a888983381dc46a96970d3b075081384de1f7a3100aaf721bfe9
#   Stored in directory: c:\users\raymond\appdata\local\pip\cache\wheels\35\e4\69\cb99d996d14a2971b79b990d68b05a17d58ce530ff96090dfc
# Successfully built imutils
# ...

# %%
# import the necessary packages
from imutils import face_utils
import dlib
import cv2
 
# initialize dlib's face detector (HOG-based) and then create
# the facial landmark predictor
p = "shape_predictor_68_face_landmarks.dat"
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor(p)

cap = cv2.VideoCapture(0)
 
while True:
    # load the input image and convert it to grayscale
    _, image = cap.read()
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        
    # detect faces in the grayscale image
    rects = detector(gray, 0)
    
    # loop over the face detections
    for (i, rect) in enumerate(rects):
        # determine the facial landmarks for the face region, then
        # convert the facial landmark (x, y)-coordinates to a NumPy
        # array
        shape = predictor(gray, rect)
        shape = face_utils.shape_to_np(shape)
    
        # loop over the (x, y)-coordinates for the facial landmarks
        # and draw them on the image
        for (x, y) in shape:
            cv2.circle(image, (x, y), 2, (0, 255, 0), -1)
    
    # show the output image with the face detections + facial landmarks
    cv2.imshow("Output", image)
    k = cv2.waitKey(5) & 0xFF
    if k == 27:
        break

cv2.destroyAllWindows()
cap.release()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26568\3667433214.py in <module>
#       1 # import the necessary packages
#       2 from imutils import face_utils
# ----> 3 import dlib
#       4 import cv2
#       5
#
# ModuleNotFoundError: No module named 'dlib'
